# %% [markdown]
# # pivot_table__1

# %%
#%load_ext nb_black
# %load_ext pycodestyle_magic
# %pycodestyle_on

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/wtm695450085/Perfect-Plots__GIP/master/kaggletrain.csv")
df.head(2)
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C
# 1:80: E501 line too long (108 > 79 characters)

# %%
df.pivot(index='Name', columns='Sex', values='Age')
# Out:
# Sex                                    female  male
# Name
# Abbing, Mr. Anthony                       NaN  42.0
# Abbott, Mr. Rossmore Edward               NaN  16.0
# Abbott, Mrs. Stanton (Rosa Hunt)         35.0   NaN
# Abelson, Mr. Samuel                       NaN  30.0
# Abelson, Mrs. Samuel (Hannah Wizosky)    28.0   NaN
# ...                                       ...   ...
# de Mulder, Mr. Theodore                   NaN  30.0
# de Pelsmaeker, Mr. Alfons                 NaN  16.0
# del Carlo, Mr. Sebastiano                 NaN  29.0
# van Billiard, Mr. Austin Blyler           NaN  40.5
# van Melkebeke, Mr. Philemon               NaN   NaN
#
# [891 rows x 2 columns]

# %%
df.pivot_table(index='Age', columns = 'Sex', values='Ticket',aggfunc='count').reset_index()
# Out:
# Sex    Age  female  male
# 0     0.42     NaN   1.0
# 1     0.67     NaN   1.0
# 2     0.75     2.0   NaN
# 3     0.83     NaN   2.0
# 4     0.92     NaN   1.0
# ..     ...     ...   ...
# 83   70.00     NaN   2.0
# 84   70.50     NaN   1.0
# 85   71.00     NaN   2.0
# 86   74.00     NaN   1.0
# 87   80.00     NaN   1.0
#
# [88 rows x 3 columns]
# 1:36: E251 unexpected spaces around keyword / parameter equals
# 1:38: E251 unexpected spaces around keyword / parameter equals
# 1:61: E231 missing whitespace after ','
# 1:80: E501 line too long (91 > 79 characters)

# %% [markdown]
# Tabela przestawna  pokazująca koszt biletu ofiar katastrofy podzielonych ze względu na wiek.

# %%
df.pivot_table(index='Age', columns = 'Sex', values='Fare',aggfunc='sum').reset_index()
# Out:
# Sex    Age   female      male
# 0     0.42      NaN    8.5167
# 1     0.67      NaN   14.5000
# 2     0.75  38.5166       NaN
# 3     0.83      NaN   47.7500
# 4     0.92      NaN  151.5500
# ..     ...      ...       ...
# 83   70.00      NaN   81.5000
# 84   70.50      NaN    7.7500
# 85   71.00      NaN   84.1584
# 86   74.00      NaN    7.7750
# 87   80.00      NaN   30.0000
#
# [88 rows x 3 columns]
# 1:36: E251 unexpected spaces around keyword / parameter equals
# 1:38: E251 unexpected spaces around keyword / parameter equals
# 1:59: E231 missing whitespace after ','
# 1:80: E501 line too long (87 > 79 characters)

# %% [markdown]
# # airports.csv

# %%
df = pd.read_csv("https://raw.githubusercontent.com/wtm695450085/Perfect-Plots__GIP/master/airports.csv")
df.head(2)
# Out:
#        id ident           type                  name  latitude_deg  \
# 0    6523   00A       heliport     Total Rf Heliport     40.070801
# 1  323361  00AA  small_airport  Aero B Ranch Airport     38.704022
#
#    longitude_deg  elevation_ft continent iso_country iso_region municipality  \
# 0     -74.933601          11.0       NaN          US      US-PA     Bensalem
# 1    -101.473911        3435.0       NaN          US      US-KS        Leoti
#
#   scheduled_service gps_code iata_code local_code home_link wikipedia_link  \
# 0                no      00A       NaN        00A       NaN            NaN
# 1                no     00AA       NaN       00AA       NaN            NaN
#
#   keywords
# 0      NaN
# 1      NaN
# 1:80: E501 line too long (105 > 79 characters)

# %%
df.pivot_table(index='iso_country',
               columns='type',
               values='continent',
               aggfunc='count',
               margins=True,
               margins_name='RAZEM')
# Out:
# type         balloonport  closed  heliport  large_airport  medium_airport  \
# iso_country
# AD                   NaN     NaN       2.0            NaN             NaN
# AE                   NaN     4.0      21.0            4.0             8.0
# AF                   NaN     2.0       3.0            NaN             8.0
# AG                   NaN     NaN       NaN            NaN             0.0
# AI                   NaN     NaN       NaN            NaN             0.0
# ...                  ...     ...       ...            ...             ...
# ZA                   NaN    12.0       4.0            5.0            57.0
# ZM                   NaN     1.0       NaN            1.0             7.0
# ZW                   NaN     2.0       NaN            1.0             8.0
# ZZ                   NaN     7.0       NaN            NaN             NaN
# RAZEM                5.0  1496.0    4246.0          415.0          3293.0
#
# type         seaplane_base  small_airport    RAZEM
# iso_country
# AD                     NaN            NaN      2.0
# AE                     3.0           16.0     56.0
# AF                     NaN           51.0     64.0
# AG                     NaN            0.0      NaN
# AI                     NaN            NaN      NaN
# ...                    ...            ...      ...
# ZA                     NaN          408.0    486.0
# ZM                     NaN           94.0    103.0
# ZW                     NaN          127.0    138.0
# ZZ                     NaN            NaN      7.0
# RAZEM                 60.0        17548.0  27063.0
#
# [244 rows x 8 columns]

# %%
df.pivot_table(index=['iso_country', 'type'],
               values='name',
               aggfunc='count').reset_index()
# Out:
#     iso_country            type  name
# 0            AD        heliport     2
# 1            AE          closed     4
# 2            AE        heliport    21
# 3            AE   large_airport     4
# 4            AE  medium_airport     8
# ..          ...             ...   ...
# 837          ZW          closed     2
# 838          ZW   large_airport     1
# 839          ZW  medium_airport     8
# 840          ZW   small_airport   127
# 841          ZZ          closed     7
#
# [842 rows x 3 columns]

# %% [markdown]
# # WEEK

# %%
df = pd.read_csv(
    "https://raw.githubusercontent.com/wtm695450085/Perfect-Plots__GIP/master/Energy.csv",
    index_col=0, parse_dates=["Date"]
)
df.head()
# Out:
#         Date  Consumption  Wind  Solar  Wind+Solar
# 0 2006-01-01     1069.184   NaN    NaN         NaN
# 1 2006-01-02     1380.521   NaN    NaN         NaN
# 2 2006-01-03     1442.533   NaN    NaN         NaN
# 3 2006-01-04     1457.217   NaN    NaN         NaN
# 4 2006-01-05     1477.131   NaN    NaN         NaN
# 2:80: E501 line too long (90 > 79 characters)

# %%
df['year'] = df['Date'].dt.year
df['month'] = df['Date'].dt.month
df['week'] = df['Date'].dt.week
# Out:
# /home/wojciech/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.figsize': (6, 3), 'figure.dpi': 120})

kot3.plot()
# Out:
# <AxesSubplot:xlabel='week'>

# %% [markdown]
# # Chce porównać dwa konkretne lata: 2009 i  2014

# %%
kot3 = kot3.reset_index()
kot3.head(2)
# Out:
# year  week         2006         2007         2008         2009         2010  \
# 0        1  1381.300143  1323.127625  1288.477111  1122.246250  1405.912000
# 1        2  1486.730286  1483.826143  1482.137143  1366.170429  1454.283714
#
# year         2011         2012         2013         2014        2015  \
# 0     1370.802714  1233.527000  1103.339250  1257.046500  1219.08625
# 1     1429.844143  1361.100714  1322.050286  1458.074857  1459.50000
#
# year         2016         2017
# 0     1429.120143  1468.473429
# 1     1508.874714  1544.333571

# %%
nor = kot3.pivot_table(index='week',
                       values=[2006,2014],
                       aggfunc='mean')

nor[:4]
# Out:
# year         2006         2014
# week
# 1     1381.300143  1257.046500
# 2     1486.730286  1458.074857
# 3     1490.031143  1508.738000
# 4     1514.176857  1541.613000
# 3:36: E231 missing whitespace after ','

# %%
nor.plot()
# Out:
# <AxesSubplot:xlabel='week'>

# %% [markdown]
# # Chce porównać dwa konkretne lata: 2009 i  2014 w okresie 20 - 30 week

# %%
dfk = kot3.loc[(kot3['week'] >= 20) & (kot3['week'] <= 30), :]
dfk
# Out:
# year  week         2006         2007         2008         2009         2010  \
# 19      20  1280.558714  1227.332571  1240.749571  1210.185857  1269.178571
# 20      21  1216.081000  1285.750571  1243.693143  1089.202143  1202.008000
# 21      22  1264.780000  1230.739571  1324.166429  1169.190429  1203.472143
# 22      23  1195.360286  1247.152286  1304.145000  1121.186857  1273.746000
# 23      24  1220.539143  1311.017429  1284.444714  1144.861571  1246.697714
# 24      25  1273.592286  1307.390714  1285.255857  1182.918000  1238.947143
# 25      26  1254.896857  1311.888714  1297.168429  1188.134000  1281.304000
# 26      27  1279.510571  1300.935286  1293.684857  1193.408857  1280.432571
# 27      28  1260.945286  1279.052429  1282.277429  1168.313714  1274.332286
# 28      29  1261.179714  1287.784000  1268.052714  1164.737000  1257.932857
# 29      30  1263.756571  1276.187286  1259.492857  1143.786714  1220.485429
#
# year         2011         2012         2013         2014         2015  \
# 19    1314.053143  1192.863000  1216.388857  1372.636143  1258.204714
# 20    1312.740143  1267.071000  1179.325857  1357.924714  1320.840714
# 21    1222.447429  1189.975571  1165.471429  1277.319000  1277.022429
# 22    1287.367143  1179.202143  1190.125429  1332.461714  1287.911143
# 23    1243.639143  1247.903857  1194.735857  1289.950714  1333.911571
# 24    1234.298143  1244.830714  1220.914571  1273.486000  1325.489571
# 25    1281.261286  1235.240714  1183.650857  1338.999714  1332.166286
# 26    1294.264429  1251.404857  1204.902429  1334.192429  1359.002429
# 27    1280.724714  1211.444571  1198.380429  1343.773429  1336.907714
# 28    1250.456714  1192.170571  1203.554857  1346.845857  1344.087714
# 29    1211.268286  1219.103286  1222.830143  1342.466857  1332.267000
#
# year         2016         2017
# 19    1292.415000  1331.964714
# 20    1301.794286  1249.245286
# 21    1336.100429  1325.870857
# 22    1321.124143  1254.762857
# 23    1318.576714  1267.952571
# 24    1336.252714  1346.359000
# 25    1326.099429  1325.580714
# 26    1322.204857  1314.684286
# 27    1312.309714  1297.575286
# 28    1319.934714  1299.805429
# 29    1301.799571  1279.216571

# %%
nor = dfk.pivot_table(index='week',
                       values=[2006, 2014],
                       aggfunc='mean')

nor.plot()
# Out:
# <AxesSubplot:xlabel='week'>
# 2:24: E127 22
# 3:24: E127 22

# %%
url = 'https://raw.githubusercontent.com/wtm695450085/Perfect-Plots__GIP/master/drinksbycountry.csv'
df = pd.read_csv(url)
df.head(2)
# Out:
#    Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0           0  Afghanistan              0                0              0
# 1           1      Albania             89              132             54
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 1:80: E501 line too long (100 > 79 characters)

# %%
df.pivot_table(index=['continent'],
               values=['beer_servings',
                       'wine_servings',
                       'spirit_servings'],
               aggfunc='mean').reset_index()
# Out:
#        continent  beer_servings  spirit_servings  wine_servings
# 0         Africa      61.471698        16.339623      16.264151
# 1           Asia      37.045455        60.840909       9.068182
# 2         Europe     193.777778       132.555556     142.222222
# 3  North America     145.434783       165.739130      24.521739
# 4        Oceania      89.687500        58.437500      35.625000
# 5  South America     175.083333       114.750000      62.416667

# %%
df.pivot_table(index='continent',
               values=['beer_servings',
                       'spirit_servings',
                       'wine_servings'],
               aggfunc='mean',
               margins=True,
               margins_name='Średnia:')
# Out:
#                beer_servings  spirit_servings  wine_servings
# continent
# Africa             61.471698        16.339623      16.264151
# Asia               37.045455        60.840909       9.068182
# Europe            193.777778       132.555556     142.222222
# North America     145.434783       165.739130      24.521739
# Oceania            89.687500        58.437500      35.625000
# South America     175.083333       114.750000      62.416667
# Średnia:          106.160622        80.994819      49.450777

# %%
df.pivot_table(index='continent',
               values=['beer_servings', 'spirit_servings', 'wine_servings'],
               aggfunc='mean',
               margins=True,
               margins_name='Średnia:').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='continent'>

# %%
url = 'https://raw.githubusercontent.com/wtm695450085/Perfect-Plots__GIP/master/uforeports.csv'
df = pd.read_csv(url)
df.head(2)
# Out:
#    Unnamed: 0         City Colors Reported Shape Reported State  \
# 0           0       Ithaca             NaN       TRIANGLE    NY
# 1           1  Willingboro             NaN          OTHER    NJ
#
#               Time
# 0   6/1/1930 22:00
# 1  6/30/1930 20:00
# 1:80: E501 line too long (95 > 79 characters)

# %%
df.pivot_table(index=['Shape Reported'],
               values=['State'],
               aggfunc='count',
               margins=True).reset_index()
# Out:
#    Shape Reported  State
# 0         CHEVRON    248
# 1           CIGAR    618
# 2          CIRCLE   1367
# 3            CONE     60
# 4        CRESCENT      2
# 5           CROSS     36
# 6        CYLINDER    295
# 7           DELTA      7
# 8         DIAMOND    234
# 9            DISK   2125
# 10           DOME      1
# 11            EGG    197
# 12       FIREBALL   1040
# 13          FLARE      1
# 14          FLASH    188
# 15      FORMATION    434
# 16        HEXAGON      1
# 17          LIGHT   2805
# 18          OTHER   1402
# 19           OVAL    846
# 20        PYRAMID      1
# 21      RECTANGLE    303
# 22          ROUND      2
# 23         SPHERE   1055
# 24       TEARDROP    119
# 25       TRIANGLE   1889
# 26        VARIOUS    333
# 27            All  15609

# %%
RODZAJE UFO STRUKTURA

# %%
df.pivot_table(index='Shape Reported',
               values='State',
               aggfunc='count').plot(kind='pie',
                                     subplots=True,
                                     legend=False)
# Out:
# array([<AxesSubplot:ylabel='State'>], dtype=object)

# %%
url = 'https://raw.githubusercontent.com/wtm695450085/Perfect-Plots__GIP/master/WorldHappinessReport.csv'
df = pd.read_csv(url)
df.head(2)
# Out:
#   Unnamed: 0      Country                      Region  Happiness Rank  \
# 0          0  Afghanistan               Southern Asia           153.0
# 1          1      Albania  Central and Eastern Europe            95.0
#
#    Happiness Score  Economy (GDP per Capita)   Family  \
# 0            3.575                   0.31982  0.30285
# 1            4.959                   0.87867  0.80434
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.30335  0.23414                        0.09719
# 1                   0.81325  0.35733                        0.06413
#
#    Generosity  Dystopia Residual    Year
# 0     0.36510            1.95210  2015.0
# 1     0.14272            1.89894  2015.0
# 1:80: E501 line too long (105 > 79 characters)

# %%
df2 = df.pivot_table(index='Region',
                     values='Happiness Score', aggfunc='mean')
df2.sort_values('Happiness Score').plot(kind='bar',
                                        title="Zadowolenie na świecie")
# Out:
# <AxesSubplot:title={'center':'Zadowolenie na świecie'}, xlabel='Region'>

# %%
df2.sort_values('Happiness Score').plot(kind='barh',
                                        title="Zadowolenie na świecie",
                                        legend=False,
                                        color=['r'])
# Out:
# <AxesSubplot:title={'center':'Zadowolenie na świecie'}, ylabel='Region'>

# %%
pd.pivot_table(df, index=['Region', 'Year'], values="Happiness Score")
# Out:
#                                         Happiness Score
# Region                          Year
# Australia and New Zealand       2015.0         7.285000
#                                 2016.0         7.323500
#                                 2017.0         7.299000
# Central and Eastern Europe      2015.0         5.332931
#                                 2016.0         5.370690
#                                 2017.0         5.409931
# Eastern Asia                    2015.0         5.626167
#                                 2016.0         5.624167
#                                 2017.0         5.681600
# Latin America and Caribbean     2015.0         6.144682
#                                 2016.0         6.101750
#                                 2017.0         5.957818
# Middle East and Northern Africa 2015.0         5.406900
#                                 2016.0         5.386053
#                                 2017.0         5.369684
# North America                   2015.0         7.273000
#                                 2016.0         7.254000
#                                 2017.0         7.154500
# Southeastern Asia               2015.0         5.317444
#                                 2016.0         5.338889
#                                 2017.0         5.444875
# Southern Asia                   2015.0         4.580857
#                                 2016.0         4.563286
#                                 2017.0         4.628429
# Sub-Saharan Africa              2015.0         4.202800
#                                 2016.0         4.136421
#                                 2017.0         4.111949
# Western Europe                  2015.0         6.689619
#                                 2016.0         6.685667
#                                 2017.0         6.703714

# %%
df.pivot_table(index=['Region', 'Year'],
               values='Happiness Score').plot(kind='barh',
                                              figsize=(3, 7),
                                              color=('b', 'g', 'y'),
                                              legend=False)
# Out:
# <AxesSubplot:ylabel='Region,Year'>

# %%
pd.pivot_table(df, index='Region', columns='Year', values="Happiness Score")
# Out:
# Year                               2015.0    2016.0    2017.0
# Region
# Australia and New Zealand        7.285000  7.323500  7.299000
# Central and Eastern Europe       5.332931  5.370690  5.409931
# Eastern Asia                     5.626167  5.624167  5.681600
# Latin America and Caribbean      6.144682  6.101750  5.957818
# Middle East and Northern Africa  5.406900  5.386053  5.369684
# North America                    7.273000  7.254000  7.154500
# Southeastern Asia                5.317444  5.338889  5.444875
# Southern Asia                    4.580857  4.563286  4.628429
# Sub-Saharan Africa               4.202800  4.136421  4.111949
# Western Europe                   6.689619  6.685667  6.703714

# %%
DD = pd.pivot_table(df, index='Region',
                    columns='Year',
                    values="Happiness Score")
DD.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
pd.pivot_table(df, index='Region',
               values="Happiness Score",
               aggfunc=[np.mean, np.median, min, max, np.std])
# Out:
#                                            mean          median  \
#                                 Happiness Score Happiness Score
# Region
# Australia and New Zealand              7.302500          7.2995
# Central and Eastern Europe             5.371184          5.4010
# Eastern Asia                           5.641765          5.8350
# Latin America and Caribbean            6.069074          6.1265
# Middle East and Northern Africa        5.387879          5.3175
# North America                          7.227167          7.2175
# Southeastern Asia                      5.364077          5.2965
# Southern Asia                          4.590857          4.6080
# Sub-Saharan Africa                     4.150957          4.1390
# Western Europe                         6.693000          6.9070
#
#                                             min             max  \
#                                 Happiness Score Happiness Score
# Region
# Australia and New Zealand                 7.284           7.334
# Central and Eastern Europe                4.096           6.609
# Eastern Asia                              4.874           6.422
# Latin America and Caribbean               3.603           7.226
# Middle East and Northern Africa           3.006           7.278
# North America                             6.993           7.427
# Southeastern Asia                         3.819           6.798
# Southern Asia                             3.360           5.269
# Sub-Saharan Africa                        2.693           5.648
# Western Europe                            4.857           7.587
#
#                                             std
#                                 Happiness Score
# Region
# Australia and New Zealand              0.020936
# Central and Eastern Europe             0.578274
# Eastern Asia                           0.515907
# Latin America and Caribbean            0.728157
# Middle East and Northern Africa        1.031656
# North America                          0.179331
# Southeastern Asia                      0.882637
# Southern Asia                          0.535978
# Sub-Saharan Africa                     0.584945
# Western Europe                         0.777886

# %%
pd.pivot_table(df, index='Region',
               values="Happiness Score",
               aggfunc='count')
df.Region.value_counts().to_frame()
# Out:
#                                  Region
# Sub-Saharan Africa                  129
# Central and Eastern Europe           87
# Latin America and Caribbean          72
# Western Europe                       63
# Middle East and Northern Africa      60
# Southeastern Asia                    27
# Eastern Asia                         21
# Southern Asia                        21
# North America                         6
# Australia and New Zealand             6
